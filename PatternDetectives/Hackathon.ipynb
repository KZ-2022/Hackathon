# %%
# %matplotlib inline
import mxnet as mx
from mxnet import gluon
from gluonts.dataset.common import ListDataset
from gluonts.dataset.field_names import FieldName
from gluonts.model import deepar
# from gluonts.mx import DeepAREstimator
from gluonts.mx.trainer import Trainer
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.evaluation import Evaluator
from gluonts.dataset import common
from gluonts.model import deepar
from gluonts.mx.distribution import DistributionOutput, GaussianOutput,NegativeBinomialOutput,StudentTOutput
from gluonts.evaluation import make_evaluation_predictions
from gluonts.mx.trainer.callback import TrainingHistory
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
import seaborn as sns
import json
import os
import datetime
from itertools import islice
from pathlib import Path
from sklearn import preprocessing
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import scipy.stats
import datetime
from dateutil.relativedelta import relativedelta
import optuna
warnings.filterwarnings("ignore")

mx.random.seed(546781345)
np.random.seed(546781345)

# %%
df = pd.read_csv('monthly_data.csv')

# %%
df
# Out:
#     Unnamed: 0       datum  RemediMax    VitaFlux  SynaptraZol  NeuroRevive  \
# 0            0  30-01-2017  127.69000   99.090000   152.100000   878.030000
# 1            1  27-02-2017  133.32000  126.050000   177.000000  1001.900000
# 2            2  30-03-2017  137.44000   92.950000   147.655000   779.275000
# 3            3  29-04-2017  113.10000   89.475000   130.900000   698.500000
# 4            4  30-05-2017  101.79000  119.933000   132.100000   628.780000
# 5            5  29-06-2017  112.07000   94.710000   122.900000   548.225000
# 6            6  30-07-2017  117.06000   95.010000   129.300000   491.900000
# 7            7  30-08-2017  134.79000   99.780000   123.800000   583.850000
# 8            8  29-09-2017  108.78000  109.094000   122.100000   887.820000
# 9            9  30-10-2017  154.75000  185.241000   191.600000  1856.815000
# 10          10  29-11-2017  138.08000  100.860000   142.700000   723.800000
# 11          11  30-12-2017  131.90000  121.401000   111.124000  1015.660000
# 12          12  30-01-2018  135.91000  130.349000   141.000000  1044.240000
# 13          13  27-02-2018  115.71000  123.740000   131.830000   953.252000
# 14          14  30-03-2018  156.04000  129.386000   133.800000  1084.850000
# 15          15  29-04-2018  154.50000  101.115000   122.100000   940.170000
# 16          16  30-05-2018  160.02000  119.117000   136.040000   765.900000
# 17          17  29-06-2018  151.87000  113.690000   145.460000   746.788000
# 18          18  30-07-2018  175.61000  113.810000   125.500000   708.828000
# 19          19  30-08-2018  181.69000  144.519000   133.400000   790.788000
# 20          20  29-09-2018  166.22000  134.122000   110.400000   852.125000
# 21          21  30-10-2018  195.81000  127.231000   146.200000  1574.335000
# 22          22  29-11-2018  152.78000  128.233000   145.900000  1277.725000
# 23          23  30-12-2018  159.46000  131.291000   137.000000  1258.349000
# 24          24  30-01-2019  171.65000  128.402000   172.500000  1476.324000
# 25          25  28-02-2019  173.81000  137.528000   134.200000  1224.862000
# 26          26  31-03-2019  156.64000  180.589000   148.400000  1150.700000
# 27          27  30-04-2019  166.61000  146.526000   147.700000   998.337000
# 28          28  31-05-2019  167.36000  120.861000   130.550000   997.150000
# 29          29  30-06-2019  169.67000  114.961000   117.750000   760.050000
# 30          30  31-07-2019  203.97000  141.019000   137.900000   652.362000
# 31          31  31-08-2019  211.13000  114.375000   132.700000   753.050000
# 32          32  30-09-2019  172.96000  126.218000   116.700000  1118.699000
# 33          33  31-10-2019  186.76000  142.056000   160.150000  1617.275000
# 34          34  30-11-2019  175.18000  116.850000   133.850000  1062.686000
# 35          35  31-12-2019  169.32000  135.056000   132.400000  1624.335000
# 36          36  31-01-2020  152.24017  119.301339   121.553542   923.158119
# 37          37  28-02-2020  139.69000  103.517000    97.000000   526.350000
# 38          38  30-03-2020  162.85000  111.055000   107.350000   612.500000
# 39          39  29-04-2020  155.61000  101.215000   100.500000   540.200000
# 40          40  30-05-2020  143.66000  118.125000    98.950000   547.940000
# 41          41  29-06-2020  122.33000  103.006000   119.600000   496.100000
# 42          42  30-07-2020  159.67000  116.206000    75.200000   479.350000
# 43          43  30-08-2020  170.15000  112.470000    84.400000   549.300000
# 44          44  29-09-2020  138.33000  118.711000    88.150000   863.750000
# 45          45  30-10-2020  137.64000   88.737000   100.400000  1184.350000
# 46          46  29-11-2020  163.85000  119.780000   104.450000   867.899000
# 47          47  30-12-2020  160.01000  121.663000   115.150000  1007.180000
# 48          48  30-01-2021  132.28000  109.446000   101.150000  1134.325000
# 49          49  27-02-2021  128.36000  132.804000   114.650000  1255.374000
# 50          50  30-03-2021  146.16000  111.764000   122.300000   999.123000
# 51          51  29-04-2021  170.02000  107.723000    84.600000   836.037000
# 52          52  30-05-2021  160.52000  103.522000    89.400000   644.648000
# 53          53  29-06-2021  141.18000  114.226000    86.800000   584.343000
# 54          54  30-07-2021  150.18000  132.549000    87.200000   679.350000
# 55          55  30-08-2021  140.00000  114.719000    88.250000   733.838000
# 56          56  29-09-2021  153.52000  114.992000    86.500000  1058.262000
# 57          57  30-10-2021  144.71000  129.400000    76.050000  1129.275000
# 58          58  29-11-2021  172.29000  105.487000   102.150000   995.150000
# 59          59  30-12-2021  147.71000  113.024000    84.750000  1213.950000
#
#      Immunoxen  RemediSol   Vitalisol  RestoraZen
# 0   354.000000  50.000000  112.000000   48.200000
# 1   347.000000  31.000000  122.000000   36.200000
# 2   232.000000  20.000000  112.000000   85.400000
# 3   209.000000  18.000000   97.000000   73.700000
# 4   270.000000  23.000000  107.000000  123.700000
# 5   323.000000  23.000000   57.000000  109.300000
# 6   348.000000  21.000000   61.000000   69.100000
# 7   420.000000  29.000000   37.000000   70.800000
# 8   399.000000  14.000000  115.000000   58.800000
# 9   472.000000  30.000000  182.000000   74.500000
# 10  489.000000  19.000000  112.000000   45.200000
# 11  492.000000  25.000000  163.000000   33.400000
# 12  463.000000  24.000000  177.250000   42.000000
# 13  243.000000   9.000000  208.000000   47.000000
# 14  208.000000  13.000000  195.000000   54.000000
# 15  192.000000   5.000000   97.000000  112.000000
# 16  194.000000  10.000000  100.000000  159.500000
# 17  217.000000  12.000000  193.000000  125.800000
# 18  203.000000   6.000000   60.000000  130.300000
# 19  265.500000  15.000000   45.000000   83.700000
# 20  243.500000  11.000000   91.000000   71.000000
# 21  222.000000   8.000000  184.000000   72.000000
# 22  228.000000  18.000000  195.000000   44.000000
# 23  286.000000  28.000000  231.000000   41.730000
# 24  248.000000  24.000000  174.000000   56.500000
# 25  239.000000  20.000000  245.000000   58.000000
# 26  250.000000  13.000000  253.000000   97.840000
# 27  318.000000  18.000000  216.000000  162.400000
# 28  275.000000  18.000000  131.000000  137.100000
# 29  311.000000  20.000000  127.000000  134.800000
# 30  240.000000   8.000000  109.000000  116.830000
# 31  275.500000  12.000000  116.000000   85.300000
# 32  307.000000  18.000000  121.000000   69.300000
# 33  312.000000  11.000000  220.000000   60.900000
# 34  246.000000  27.000000  150.000000   51.200000
# 35  257.000000  18.000000  275.000000   34.900000
# 36  270.198305  17.847458  164.190678   84.623898
# 37  144.000000   7.000000  117.000000   30.600000
# 38  165.000000   9.000000  139.000000  100.100000
# 39  132.000000   9.000000  209.000000  122.400000
# 40  148.000000  23.000000  128.000000  161.810000
# 41  163.000000   8.000000  163.000000  151.900000
# 42  219.000000  15.000000  115.000000   81.100000
# 43  239.000000  12.000000   75.000000   60.100000
# 44  223.000000  23.000000  139.000000   66.900000
# 45  226.000000  15.000000  247.000000   51.000000
# 46  192.000000  15.000000  196.000000   46.600000
# 47  226.000000   6.000000  204.000000   47.100000
# 48  229.000000  11.000000  219.000000   49.500000
# 49  268.000000  12.000000  253.000000   39.060000
# 50  381.000000  42.000000  269.000000   85.500000
# 51  289.000000  21.000000  229.000000  197.100000
# 52  259.000000  13.000000  192.000000  213.040000
# 53  248.000000  18.000000  101.000000  120.800000
# 54  283.000000  19.000000   90.000000  122.200000
# 55  253.000000  20.000000  159.000000  103.100000
# 56  263.000000  12.000000  205.000000   88.100000
# 57  287.000000  25.000000  353.000000   76.900000
# 58  252.200000  22.000000  311.000000   48.400000
# 59  254.000000  27.000000  384.000000   53.100000

# %%
df['quarters'] = pd.to_datetime(df['datum']).dt.quarter

# %%
freq='M'
prediction_length=10

# %%
import optuna
from optuna.samplers import TPESampler

# %%
df_train = df[:-10]

# %%
df_predict = df

# %%
items = ['RemediMax', 'VitaFlux', 'SynaptraZol',
       'NeuroRevive', 'Immunoxen', 'RemediSol', 'Vitalisol', 'RestoraZen']

# %%
dynamic_real = pd.DataFrame(columns=items)

cat_data = pd.DataFrame(columns = ['ID','Therapeutic_area'])
cat_data['ID'] = items
cat_data['Therapeutic_area'] = ['Neuroscience','Immunology','Oncology',
                               'Diabetes','Anti-infectives','Immunology','Diabetes','Neuroscience']
label_encoder = preprocessing.LabelEncoder()
cat_data['Therapeutic_area'] = label_encoder.fit_transform(cat_data['Therapeutic_area'])
cat_data
# Out:
#             ID  Therapeutic_area
# 0    RemediMax                 3
# 1     VitaFlux                 2
# 2  SynaptraZol                 4
# 3  NeuroRevive                 1
# 4    Immunoxen                 0
# 5    RemediSol                 2
# 6    Vitalisol                 1
# 7   RestoraZen                 3

# %%
train_ds = ListDataset([
    {
        FieldName.TARGET: df_train[id].values,
        FieldName.START: df_train['datum'].values[0],
        FieldName.FEAT_STATIC_CAT:[cat_data[cat_data['ID']==id]['Therapeutic_area'].values[0]],
        FieldName.FEAT_DYNAMIC_REAL:[df_train['quarters'].values.T]
        
    }
    for id in items
],freq='M')

# %%
predict_ds = ListDataset([
    {
        FieldName.TARGET: df_predict[id].values,
        FieldName.START: df_train['datum'].values[0],
        FieldName.FEAT_STATIC_CAT:[cat_data[cat_data['ID']==id]['Therapeutic_area'].values[0]],
        FieldName.FEAT_DYNAMIC_REAL:[df_predict['quarters'].values.T]
    }
    for id in items
],freq='M')

# %%
def SMAPE(predictions,data):
    SMAPE = []
    data.reset_index(inplace=True)
    for id in items:
        pred_y = pd.DataFrame(predictions[id])
        pred_y.columns = ['pred_y']
        Output = pd.concat([data[id],pred_y],axis=1)
        Output['Diff_Val']=abs(Output[id]-Output['pred_y'])
        Output['sum_Val']=abs(Output[id]) + abs(Output['pred_y'])
        Output['Div_val']=Output['Diff_Val']/(Output['sum_Val']+0.0001)
        smape = (2*sum(Output['Div_val']))/Output.shape[0] 
        SMAPE.append(smape)
    return sum(SMAPE)/len(SMAPE)

# %%
def objective(trial):
    num_layers= trial.suggest_int('num_layers',2,4)  
    num_cells = trial.suggest_int('num_cells',32,64)
    learning_rate= trial.suggest_float('learning_rate',0.001,0.01)
    dropout_rate = trial.suggest_float('dropout_rate',0.01,0.1)
    history = TrainingHistory()
    estimator = deepar.DeepAREstimator(
                        freq=freq, 
                        prediction_length=prediction_length,
                        use_feat_static_cat=True,
                        cardinality = [cat_data['Therapeutic_area'].nunique()],
                        use_feat_dynamic_real=False,
                        num_layers=num_layers,
                        num_cells=num_cells,
                        dropout_rate = dropout_rate,
                        cell_type='lstm',
                        distr_output =NegativeBinomialOutput(),# Distribution to be used
                        trainer=Trainer(epochs=50,learning_rate=learning_rate,callbacks=[history]))
    predictor = estimator.train(training_data=train_ds)
    mx.random.seed(546781345)
    np.random.seed(546781345)
    
    forecast_it, ts_it = make_evaluation_predictions(
    dataset=predict_ds,  # test dataset
    predictor=predictor,  # predictor
    num_samples=100,  # number of sample paths we want for evaluation
    )
    forecasts = list(forecast_it)
    tss = list(ts_it)
    results_mean = pd.DataFrame()
    results_median = pd.DataFrame()
    actual = pd.DataFrame()
    results_mean['date'] = tss[0].index[-10:]
    results_median['date'] = tss[0].index[-10:]
    actual['date'] = tss[0].index[-10:]
    for i,id in zip(range(len(items)),items):
        results_mean[id] = forecasts[i].mean
        results_median[id] = forecasts[i].median
        actual[id] = tss[i].values.reshape(-1)[-10:]
    smape = SMAPE(results_median,actual)
    return smape
sampler = TPESampler(seed=546781345)
study = optuna.create_study(direction='minimize',sampler = sampler)
study.optimize(objective,n_trials=3)
# Out:
# [I 2023-06-28 02:33:54,832] A new study created in memory with name: no-name-2b87a720-1916-4649-8319-d95031f179ad
# 100%|██████████| 50/50 [00:02<00:00, 16.78it/s, epoch=1/50, avg_epoch_loss=5.23]
# 100%|██████████| 50/50 [00:02<00:00, 18.07it/s, epoch=2/50, avg_epoch_loss=4.84]
# 100%|██████████| 50/50 [00:02<00:00, 18.12it/s, epoch=3/50, avg_epoch_loss=4.61]
# 100%|██████████| 50/50 [00:02<00:00, 18.02it/s, epoch=4/50, avg_epoch_loss=4.48]
# 100%|██████████| 50/50 [00:02<00:00, 18.03it/s, epoch=5/50, avg_epoch_loss=4.39]
# 100%|██████████| 50/50 [00:02<00:00, 18.16it/s, epoch=6/50, avg_epoch_loss=4.21]
# 100%|██████████| 50/50 [00:02<00:00, 18.08it/s, epoch=7/50, avg_epoch_loss=4.02]
# 100%|██████████| 50/50 [00:02<00:00, 18.20it/s, epoch=8/50, avg_epoch_loss=3.93]
# 100%|██████████| 50/50 [00:02<00:00, 17.90it/s, epoch=9/50, avg_epoch_loss=3.91]
# 100%|██████████| 50/50 [00:02<00:00, 17.95it/s, epoch=10/50, avg_epoch_loss=2.35]
# 100%|██████████| 50/50 [00:02<00:00, 17.89it/s, epoch=11/50, avg_epoch_loss=1.08]
# 100%|██████████| 50/50 [00:02<00:00, 18.26it/s, epoch=12/50, avg_epoch_loss=0.391]
# 100%|██████████| 50/50 [00:02<00:00, 18.05it/s, epoch=13/50, avg_epoch_loss=-.0366]
# 100%|██████████| 50/50 [00:02<00:00, 18.04it/s, epoch=14/50, avg_epoch_loss=-.267]
# 100%|██████████| 50/50 [00:02<00:00, 18.15it/s, epoch=15/50, avg_epoch_loss=-.246]
# 100%|██████████| 50/50 [00:02<00:00, 17.73it/s, epoch=16/50, avg_epoch_loss=-.38]
# 100%|██████████| 50/50 [00:02<00:00, 18.19it/s, epoch=17/50, avg_epoch_loss=-.333]
# 100%|██████████| 50/50 [00:02<00:00, 18.11it/s, epoch=18/50, avg_epoch_loss=-.396]
# 100%|██████████| 50/50 [00:02<00:00, 18.08it/s, epoch=19/50, avg_epoch_loss=-.492]
# 100%|██████████| 50/50 [00:02<00:00, 18.10it/s, epoch=20/50, avg_epoch_loss=-.29]
# 100%|██████████| 50/50 [00:02<00:00, 18.22it/s, epoch=21/50, avg_epoch_loss=-.498]
# 100%|██████████| 50/50 [00:02<00:00, 17.88it/s, epoch=22/50, avg_epoch_loss=-.532]
# 100%|██████████| 50/50 [00:02<00:00, 18.08it/s, epoch=23/50, avg_epoch_loss=-.538]
# 100%|██████████| 50/50 [00:02<00:00, 17.92it/s, epoch=24/50, avg_epoch_loss=-.627]
# 100%|██████████| 50/50 [00:02<00:00, 18.03it/s, epoch=25/50, avg_epoch_loss=-.762]
# 100%|██████████| 50/50 [00:02<00:00, 18.06it/s, epoch=26/50, avg_epoch_loss=-.729]
# 100%|██████████| 50/50 [00:02<00:00, 18.11it/s, epoch=27/50, avg_epoch_loss=-.64]
# 100%|██████████| 50/50 [00:02<00:00, 18.10it/s, epoch=28/50, avg_epoch_loss=-.682]
# 100%|██████████| 50/50 [00:02<00:00, 18.02it/s, epoch=29/50, avg_epoch_loss=-.614]
# 100%|██████████| 50/50 [00:02<00:00, 17.92it/s, epoch=30/50, avg_epoch_loss=-.544]
# 100%|██████████| 50/50 [00:02<00:00, 18.10it/s, epoch=31/50, avg_epoch_loss=-.753]
# 100%|██████████| 50/50 [00:02<00:00, 18.13it/s, epoch=32/50, avg_epoch_loss=-.769]
# 100%|██████████| 50/50 [00:02<00:00, 17.91it/s, epoch=33/50, avg_epoch_loss=-.698]
# 100%|██████████| 50/50 [00:02<00:00, 17.86it/s, epoch=34/50, avg_epoch_loss=-.795]
# 100%|██████████| 50/50 [00:02<00:00, 18.02it/s, epoch=35/50, avg_epoch_loss=-.723]
# 100%|██████████| 50/50 [00:02<00:00, 18.00it/s, epoch=36/50, avg_epoch_loss=-.732]
# 100%|██████████| 50/50 [00:02<00:00, 17.94it/s, epoch=37/50, avg_epoch_loss=-.738]
# 100%|██████████| 50/50 [00:02<00:00, 17.93it/s, epoch=38/50, avg_epoch_loss=-.603]
# 100%|██████████| 50/50 [00:02<00:00, 18.07it/s, epoch=39/50, avg_epoch_loss=-.668]
# 100%|██████████| 50/50 [00:02<00:00, 18.17it/s, epoch=40/50, avg_epoch_loss=-.434]
# 100%|██████████| 50/50 [00:02<00:00, 17.94it/s, epoch=41/50, avg_epoch_loss=-.738]
# 100%|██████████| 50/50 [00:02<00:00, 17.83it/s, epoch=42/50, avg_epoch_loss=-.648]
# 100%|██████████| 50/50 [00:02<00:00, 18.07it/s, epoch=43/50, avg_epoch_loss=-.723]
# 100%|██████████| 50/50 [00:02<00:00, 18.08it/s, epoch=44/50, avg_epoch_loss=-.855]
# 100%|██████████| 50/50 [00:02<00:00, 18.09it/s, epoch=45/50, avg_epoch_loss=-.826]
# 100%|██████████| 50/50 [00:02<00:00, 17.96it/s, epoch=46/50, avg_epoch_loss=-.733]
# 100%|██████████| 50/50 [00:02<00:00, 18.04it/s, epoch=47/50, avg_epoch_loss=-.684]
# 100%|██████████| 50/50 [00:02<00:00, 18.13it/s, epoch=48/50, avg_epoch_loss=-.813]
# 100%|██████████| 50/50 [00:02<00:00, 18.08it/s, epoch=49/50, avg_epoch_loss=-.843]
# 100%|██████████| 50/50 [00:02<00:00, 18.12it/s, epoch=50/50, avg_epoch_loss=-.891]
# [I 2023-06-28 02:36:14,225] Trial 0 finished with value: 0.3053229686367558 and parameters: {'num_layers': 4, 'num_cells': 40, 'learning_rate': 0.006141287252343434, 'dropout_rate': 0.02875209047078995}. Best is trial 0 with value: 0.3053229686367558.
# 100%|██████████| 50/50 [00:02<00:00, 17.29it/s, epoch=1/50, avg_epoch_loss=5.53]
# 100%|██████████| 50/50 [00:02<00:00, 18.25it/s, epoch=2/50, avg_epoch_loss=5]
# 100%|██████████| 50/50 [00:02<00:00, 18.18it/s, epoch=3/50, avg_epoch_loss=4.76]
# 100%|██████████| 50/50 [00:02<00:00, 18.06it/s, epoch=4/50, avg_epoch_loss=4.71]
# 100%|██████████| 50/50 [00:02<00:00, 18.35it/s, epoch=5/50, avg_epoch_loss=4.56]
# 100%|██████████| 50/50 [00:02<00:00, 18.36it/s, epoch=6/50, avg_epoch_loss=4.46]
# 100%|██████████| 50/50 [00:02<00:00, 18.37it/s, epoch=7/50, avg_epoch_loss=4.29]
# 100%|██████████| 50/50 [00:02<00:00, 18.49it/s, epoch=8/50, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:02<00:00, 18.36it/s, epoch=9/50, avg_epoch_loss=4.09]
# 100%|██████████| 50/50 [00:02<00:00, 18.56it/s, epoch=10/50, avg_epoch_loss=4.2]
# 100%|██████████| 50/50 [00:02<00:00, 18.28it/s, epoch=11/50, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:02<00:00, 18.33it/s, epoch=12/50, avg_epoch_loss=3.86]
# 100%|██████████| 50/50 [00:02<00:00, 18.39it/s, epoch=13/50, avg_epoch_loss=3.87]
# 100%|██████████| 50/50 [00:02<00:00, 18.47it/s, epoch=14/50, avg_epoch_loss=3.05]
# 100%|██████████| 50/50 [00:02<00:00, 18.34it/s, epoch=15/50, avg_epoch_loss=0.996]
# 100%|██████████| 50/50 [00:02<00:00, 18.29it/s, epoch=16/50, avg_epoch_loss=0.105]
# 100%|██████████| 50/50 [00:02<00:00, 18.26it/s, epoch=17/50, avg_epoch_loss=0.478]
# 100%|██████████| 50/50 [00:02<00:00, 18.55it/s, epoch=18/50, avg_epoch_loss=-.23]
# 100%|██████████| 50/50 [00:02<00:00, 18.27it/s, epoch=19/50, avg_epoch_loss=-.315]
# 100%|██████████| 50/50 [00:02<00:00, 18.36it/s, epoch=20/50, avg_epoch_loss=-.515]
# 100%|██████████| 50/50 [00:02<00:00, 18.31it/s, epoch=21/50, avg_epoch_loss=-.423]
# 100%|██████████| 50/50 [00:02<00:00, 18.48it/s, epoch=22/50, avg_epoch_loss=-.52]
# 100%|██████████| 50/50 [00:02<00:00, 18.42it/s, epoch=23/50, avg_epoch_loss=-.101]
# 100%|██████████| 50/50 [00:02<00:00, 18.21it/s, epoch=24/50, avg_epoch_loss=-.367]
# 100%|██████████| 50/50 [00:02<00:00, 18.20it/s, epoch=25/50, avg_epoch_loss=-.686]
# 100%|██████████| 50/50 [00:02<00:00, 18.20it/s, epoch=26/50, avg_epoch_loss=-.644]
# 100%|██████████| 50/50 [00:02<00:00, 18.48it/s, epoch=27/50, avg_epoch_loss=-.647]
# 100%|██████████| 50/50 [00:02<00:00, 18.45it/s, epoch=28/50, avg_epoch_loss=-.729]
# 100%|██████████| 50/50 [00:02<00:00, 18.54it/s, epoch=29/50, avg_epoch_loss=-.679]
# 100%|██████████| 50/50 [00:02<00:00, 18.32it/s, epoch=30/50, avg_epoch_loss=-.379]
# 100%|██████████| 50/50 [00:02<00:00, 18.23it/s, epoch=31/50, avg_epoch_loss=-.701]
# 100%|██████████| 50/50 [00:02<00:00, 18.33it/s, epoch=32/50, avg_epoch_loss=-.866]
# 100%|██████████| 50/50 [00:02<00:00, 18.24it/s, epoch=33/50, avg_epoch_loss=-.799]
# 100%|██████████| 50/50 [00:02<00:00, 18.23it/s, epoch=34/50, avg_epoch_loss=-.857]
# 100%|██████████| 50/50 [00:02<00:00, 18.61it/s, epoch=35/50, avg_epoch_loss=-.852]
# 100%|██████████| 50/50 [00:02<00:00, 18.24it/s, epoch=36/50, avg_epoch_loss=-.867]
# 100%|██████████| 50/50 [00:02<00:00, 18.15it/s, epoch=37/50, avg_epoch_loss=-.504]
# 100%|██████████| 50/50 [00:02<00:00, 18.04it/s, epoch=38/50, avg_epoch_loss=-.00875]
# 100%|██████████| 50/50 [00:02<00:00, 18.22it/s, epoch=39/50, avg_epoch_loss=-.651]
# 100%|██████████| 50/50 [00:02<00:00, 18.30it/s, epoch=40/50, avg_epoch_loss=-.676]
# 100%|██████████| 50/50 [00:02<00:00, 18.45it/s, epoch=41/50, avg_epoch_loss=-.765]
# 100%|██████████| 50/50 [00:02<00:00, 18.31it/s, epoch=42/50, avg_epoch_loss=-.819]
# 100%|██████████| 50/50 [00:02<00:00, 18.40it/s, epoch=43/50, avg_epoch_loss=-.755]
# 100%|██████████| 50/50 [00:02<00:00, 18.29it/s, epoch=44/50, avg_epoch_loss=-.837]
# 100%|██████████| 50/50 [00:02<00:00, 18.32it/s, epoch=45/50, avg_epoch_loss=-.906]
# 100%|██████████| 50/50 [00:02<00:00, 18.40it/s, epoch=46/50, avg_epoch_loss=-.805]
# 100%|██████████| 50/50 [00:02<00:00, 18.49it/s, epoch=47/50, avg_epoch_loss=-.812]
# 100%|██████████| 50/50 [00:02<00:00, 18.40it/s, epoch=48/50, avg_epoch_loss=-.917]
# 100%|██████████| 50/50 [00:02<00:00, 18.36it/s, epoch=49/50, avg_epoch_loss=-.91]
# 100%|██████████| 50/50 [00:02<00:00, 18.27it/s, epoch=50/50, avg_epoch_loss=-.984]
# [I 2023-06-28 02:38:31,340] Trial 1 finished with value: 0.27835625783191065 and parameters: {'num_layers': 4, 'num_cells': 37, 'learning_rate': 0.009112679919026447, 'dropout_rate': 0.0718871964591016}. Best is trial 1 with value: 0.27835625783191065.
# 100%|██████████| 50/50 [00:02<00:00, 18.34it/s, epoch=1/50, avg_epoch_loss=5.27]
# 100%|██████████| 50/50 [00:02<00:00, 19.51it/s, epoch=2/50, avg_epoch_loss=4.94]
# 100%|██████████| 50/50 [00:02<00:00, 19.22it/s, epoch=3/50, avg_epoch_loss=4.77]
# 100%|██████████| 50/50 [00:02<00:00, 19.47it/s, epoch=4/50, avg_epoch_loss=4.7]
# 100%|██████████| 50/50 [00:02<00:00, 19.26it/s, epoch=5/50, avg_epoch_loss=4.58]
# 100%|██████████| 50/50 [00:02<00:00, 19.30it/s, epoch=6/50, avg_epoch_loss=4.45]
# 100%|██████████| 50/50 [00:02<00:00, 19.14it/s, epoch=7/50, avg_epoch_loss=4.27]
# 100%|██████████| 50/50 [00:02<00:00, 19.03it/s, epoch=8/50, avg_epoch_loss=4.18]
# 100%|██████████| 50/50 [00:02<00:00, 19.40it/s, epoch=9/50, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:02<00:00, 19.26it/s, epoch=10/50, avg_epoch_loss=4.11]
# 100%|██████████| 50/50 [00:02<00:00, 19.29it/s, epoch=11/50, avg_epoch_loss=3.76]
# 100%|██████████| 50/50 [00:02<00:00, 19.63it/s, epoch=12/50, avg_epoch_loss=1.41]
# 100%|██████████| 50/50 [00:02<00:00, 19.22it/s, epoch=13/50, avg_epoch_loss=0.739]
# 100%|██████████| 50/50 [00:02<00:00, 19.30it/s, epoch=14/50, avg_epoch_loss=0.699]
# 100%|██████████| 50/50 [00:02<00:00, 19.19it/s, epoch=15/50, avg_epoch_loss=0.36]
# 100%|██████████| 50/50 [00:02<00:00, 19.48it/s, epoch=16/50, avg_epoch_loss=0.162]
# 100%|██████████| 50/50 [00:02<00:00, 19.30it/s, epoch=17/50, avg_epoch_loss=0.0625]
# 100%|██████████| 50/50 [00:02<00:00, 19.09it/s, epoch=18/50, avg_epoch_loss=-.0652]
# 100%|██████████| 50/50 [00:02<00:00, 19.36it/s, epoch=19/50, avg_epoch_loss=-.0227]
# 100%|██████████| 50/50 [00:02<00:00, 19.15it/s, epoch=20/50, avg_epoch_loss=-.236]
# 100%|██████████| 50/50 [00:02<00:00, 19.14it/s, epoch=21/50, avg_epoch_loss=-.293]
# 100%|██████████| 50/50 [00:02<00:00, 19.02it/s, epoch=22/50, avg_epoch_loss=-.277]
# 100%|██████████| 50/50 [00:02<00:00, 19.25it/s, epoch=23/50, avg_epoch_loss=-.359]
# 100%|██████████| 50/50 [00:02<00:00, 19.19it/s, epoch=24/50, avg_epoch_loss=-.317]
# 100%|██████████| 50/50 [00:02<00:00, 19.27it/s, epoch=25/50, avg_epoch_loss=-.481]
# 100%|██████████| 50/50 [00:02<00:00, 18.88it/s, epoch=26/50, avg_epoch_loss=-.481]
# 100%|██████████| 50/50 [00:02<00:00, 19.27it/s, epoch=27/50, avg_epoch_loss=-.404]
# 100%|██████████| 50/50 [00:02<00:00, 19.28it/s, epoch=28/50, avg_epoch_loss=-.328]
# 100%|██████████| 50/50 [00:02<00:00, 19.52it/s, epoch=29/50, avg_epoch_loss=-.242]
# 100%|██████████| 50/50 [00:02<00:00, 19.21it/s, epoch=30/50, avg_epoch_loss=0.019]
# 100%|██████████| 50/50 [00:02<00:00, 19.29it/s, epoch=31/50, avg_epoch_loss=-.413]
# 100%|██████████| 50/50 [00:02<00:00, 19.27it/s, epoch=32/50, avg_epoch_loss=-.64]
# 100%|██████████| 50/50 [00:02<00:00, 19.04it/s, epoch=33/50, avg_epoch_loss=-.521]
# 100%|██████████| 50/50 [00:02<00:00, 19.06it/s, epoch=34/50, avg_epoch_loss=-.43]
# 100%|██████████| 50/50 [00:02<00:00, 19.09it/s, epoch=35/50, avg_epoch_loss=-.428]
# 100%|██████████| 50/50 [00:02<00:00, 19.08it/s, epoch=36/50, avg_epoch_loss=-.328]
# 100%|██████████| 50/50 [00:02<00:00, 19.10it/s, epoch=37/50, avg_epoch_loss=-.228]
# 100%|██████████| 50/50 [00:02<00:00, 19.09it/s, epoch=38/50, avg_epoch_loss=-.195]
# 100%|██████████| 50/50 [00:02<00:00, 19.22it/s, epoch=39/50, avg_epoch_loss=-.383]
# 100%|██████████| 50/50 [00:02<00:00, 19.44it/s, epoch=40/50, avg_epoch_loss=-.187]
# 100%|██████████| 50/50 [00:02<00:00, 19.35it/s, epoch=41/50, avg_epoch_loss=-.11]
# 100%|██████████| 50/50 [00:02<00:00, 19.43it/s, epoch=42/50, avg_epoch_loss=-.0141]
# 100%|██████████| 50/50 [00:02<00:00, 19.08it/s, epoch=43/50, avg_epoch_loss=-.522]
# 100%|██████████| 50/50 [00:02<00:00, 19.08it/s, epoch=44/50, avg_epoch_loss=-.518]
# 100%|██████████| 50/50 [00:02<00:00, 18.98it/s, epoch=45/50, avg_epoch_loss=-.218]
# 100%|██████████| 50/50 [00:02<00:00, 19.39it/s, epoch=46/50, avg_epoch_loss=-.18]
# 100%|██████████| 50/50 [00:02<00:00, 19.44it/s, epoch=47/50, avg_epoch_loss=-.273]
# 100%|██████████| 50/50 [00:02<00:00, 19.26it/s, epoch=48/50, avg_epoch_loss=-.314]
# 100%|██████████| 50/50 [00:02<00:00, 19.23it/s, epoch=49/50, avg_epoch_loss=-.25]
# 100%|██████████| 50/50 [00:02<00:00, 19.23it/s, epoch=50/50, avg_epoch_loss=-.185]
# [I 2023-06-28 02:40:41,982] Trial 2 finished with value: 0.3264776841271669 and parameters: {'num_layers': 3, 'num_cells': 61, 'learning_rate': 0.002952771059357503, 'dropout_rate': 0.029921276355596847}. Best is trial 1 with value: 0.27835625783191065.

# %%
train_ds = ListDataset([
    {
        FieldName.TARGET: df_predict[id].values,
        FieldName.START: df_train['datum'].values[0],
        FieldName.FEAT_STATIC_CAT:[cat_data[cat_data['ID']==id]['Therapeutic_area'].values[0]],       
    }
    for id in items
],freq='M')

# %%
history = TrainingHistory()
estimator = deepar.DeepAREstimator(
                    freq=freq, 
                    prediction_length=prediction_length,
                    use_feat_static_cat=True,
                    cardinality = [cat_data['Therapeutic_area'].nunique()],
                    use_feat_dynamic_real=False,
                    num_layers=study.best_params['num_layers'],
                    num_cells=study.best_params['num_cells'],
                    dropout_rate = study.best_params['dropout_rate'],
                    cell_type='lstm',
                    distr_output =NegativeBinomialOutput(),
                    trainer=Trainer(epochs=100,learning_rate=study.best_params['learning_rate'],callbacks=[history]))
predictor = estimator.train(training_data=train_ds)
# Out:
# 100%|██████████| 50/50 [00:02<00:00, 17.20it/s, epoch=1/100, avg_epoch_loss=5.32]
# 100%|██████████| 50/50 [00:02<00:00, 18.45it/s, epoch=2/100, avg_epoch_loss=4.86]
# 100%|██████████| 50/50 [00:02<00:00, 18.55it/s, epoch=3/100, avg_epoch_loss=4.71]
# 100%|██████████| 50/50 [00:02<00:00, 18.49it/s, epoch=4/100, avg_epoch_loss=4.61]
# 100%|██████████| 50/50 [00:02<00:00, 18.61it/s, epoch=5/100, avg_epoch_loss=4.42]
# 100%|██████████| 50/50 [00:02<00:00, 18.45it/s, epoch=6/100, avg_epoch_loss=4.3]
# 100%|██████████| 50/50 [00:02<00:00, 18.39it/s, epoch=7/100, avg_epoch_loss=4.19]
# 100%|██████████| 50/50 [00:02<00:00, 18.44it/s, epoch=8/100, avg_epoch_loss=4.12]
# 100%|██████████| 50/50 [00:02<00:00, 17.94it/s, epoch=9/100, avg_epoch_loss=4.06]
# 100%|██████████| 50/50 [00:02<00:00, 18.21it/s, epoch=10/100, avg_epoch_loss=3.88]
# 100%|██████████| 50/50 [00:02<00:00, 18.39it/s, epoch=11/100, avg_epoch_loss=3.59]
# 100%|██████████| 50/50 [00:02<00:00, 18.40it/s, epoch=12/100, avg_epoch_loss=1.08]
# 100%|██████████| 50/50 [00:02<00:00, 18.57it/s, epoch=13/100, avg_epoch_loss=0.41]
# 100%|██████████| 50/50 [00:02<00:00, 18.43it/s, epoch=14/100, avg_epoch_loss=0.207]
# 100%|██████████| 50/50 [00:02<00:00, 18.39it/s, epoch=15/100, avg_epoch_loss=-.283]
# 100%|██████████| 50/50 [00:02<00:00, 18.46it/s, epoch=16/100, avg_epoch_loss=-.345]
# 100%|██████████| 50/50 [00:02<00:00, 18.43it/s, epoch=17/100, avg_epoch_loss=-.232]
# 100%|██████████| 50/50 [00:02<00:00, 18.29it/s, epoch=18/100, avg_epoch_loss=-.238]
# 100%|██████████| 50/50 [00:02<00:00, 18.35it/s, epoch=19/100, avg_epoch_loss=-.361]
# 100%|██████████| 50/50 [00:02<00:00, 18.30it/s, epoch=20/100, avg_epoch_loss=-.369]
# 100%|██████████| 50/50 [00:02<00:00, 18.40it/s, epoch=21/100, avg_epoch_loss=-.403]
# 100%|██████████| 50/50 [00:02<00:00, 17.98it/s, epoch=22/100, avg_epoch_loss=-.584]
# 100%|██████████| 50/50 [00:02<00:00, 18.51it/s, epoch=23/100, avg_epoch_loss=-.334]
# 100%|██████████| 50/50 [00:02<00:00, 18.25it/s, epoch=24/100, avg_epoch_loss=-.299]
# 100%|██████████| 50/50 [00:02<00:00, 18.46it/s, epoch=25/100, avg_epoch_loss=-.493]
# 100%|██████████| 50/50 [00:02<00:00, 18.39it/s, epoch=26/100, avg_epoch_loss=-.331]
# 100%|██████████| 50/50 [00:02<00:00, 18.36it/s, epoch=27/100, avg_epoch_loss=-.371]
# 100%|██████████| 50/50 [00:02<00:00, 18.35it/s, epoch=28/100, avg_epoch_loss=-.476]
# 100%|██████████| 50/50 [00:02<00:00, 18.38it/s, epoch=29/100, avg_epoch_loss=-.587]
# 100%|██████████| 50/50 [00:02<00:00, 18.26it/s, epoch=30/100, avg_epoch_loss=-.596]
# 100%|██████████| 50/50 [00:02<00:00, 18.49it/s, epoch=31/100, avg_epoch_loss=-.384]
# 100%|██████████| 50/50 [00:02<00:00, 18.26it/s, epoch=32/100, avg_epoch_loss=-.514]
# 100%|██████████| 50/50 [00:02<00:00, 18.17it/s, epoch=33/100, avg_epoch_loss=-.518]
# 100%|██████████| 50/50 [00:02<00:00, 18.36it/s, epoch=34/100, avg_epoch_loss=-.532]
# 100%|██████████| 50/50 [00:02<00:00, 18.21it/s, epoch=35/100, avg_epoch_loss=-.44]
# 100%|██████████| 50/50 [00:02<00:00, 18.28it/s, epoch=36/100, avg_epoch_loss=-.56]
# 100%|██████████| 50/50 [00:02<00:00, 18.36it/s, epoch=37/100, avg_epoch_loss=-.577]
# 100%|██████████| 50/50 [00:02<00:00, 18.39it/s, epoch=38/100, avg_epoch_loss=-.537]
# 100%|██████████| 50/50 [00:02<00:00, 18.27it/s, epoch=39/100, avg_epoch_loss=-.467]
# 100%|██████████| 50/50 [00:02<00:00, 18.57it/s, epoch=40/100, avg_epoch_loss=-.644]
# 100%|██████████| 50/50 [00:02<00:00, 18.36it/s, epoch=41/100, avg_epoch_loss=-.567]
# 100%|██████████| 50/50 [00:02<00:00, 18.31it/s, epoch=42/100, avg_epoch_loss=-.593]
# 100%|██████████| 50/50 [00:02<00:00, 18.33it/s, epoch=43/100, avg_epoch_loss=-.348]
# 100%|██████████| 50/50 [00:02<00:00, 18.09it/s, epoch=44/100, avg_epoch_loss=-.48]
# 100%|██████████| 50/50 [00:02<00:00, 18.21it/s, epoch=45/100, avg_epoch_loss=-.648]
# 100%|██████████| 50/50 [00:02<00:00, 18.35it/s, epoch=46/100, avg_epoch_loss=-.535]
# 100%|██████████| 50/50 [00:02<00:00, 18.19it/s, epoch=47/100, avg_epoch_loss=-.41]
# 100%|██████████| 50/50 [00:02<00:00, 18.44it/s, epoch=48/100, avg_epoch_loss=-.4]
# 100%|██████████| 50/50 [00:02<00:00, 18.37it/s, epoch=49/100, avg_epoch_loss=-.341]
# 100%|██████████| 50/50 [00:02<00:00, 18.29it/s, epoch=50/100, avg_epoch_loss=-.422]
# 100%|██████████| 50/50 [00:02<00:00, 18.44it/s, epoch=51/100, avg_epoch_loss=-.38]
# 100%|██████████| 50/50 [00:02<00:00, 18.35it/s, epoch=52/100, avg_epoch_loss=-.372]
# 100%|██████████| 50/50 [00:02<00:00, 18.34it/s, epoch=53/100, avg_epoch_loss=-.0398]
# 100%|██████████| 50/50 [00:02<00:00, 18.18it/s, epoch=54/100, avg_epoch_loss=-.0778]
# 100%|██████████| 50/50 [00:02<00:00, 18.18it/s, epoch=55/100, avg_epoch_loss=-.396]
# 100%|██████████| 50/50 [00:02<00:00, 18.52it/s, epoch=56/100, avg_epoch_loss=-.574]
# 100%|██████████| 50/50 [00:02<00:00, 18.36it/s, epoch=57/100, avg_epoch_loss=-.386]
# 100%|██████████| 50/50 [00:02<00:00, 18.24it/s, epoch=58/100, avg_epoch_loss=-.314]
# 100%|██████████| 50/50 [00:02<00:00, 18.53it/s, epoch=59/100, avg_epoch_loss=-.294]
# 100%|██████████| 50/50 [00:02<00:00, 18.49it/s, epoch=60/100, avg_epoch_loss=-.374]
# 100%|██████████| 50/50 [00:02<00:00, 18.20it/s, epoch=61/100, avg_epoch_loss=-.388]
# 100%|██████████| 50/50 [00:02<00:00, 18.37it/s, epoch=62/100, avg_epoch_loss=-.388]
# 100%|██████████| 50/50 [00:02<00:00, 18.40it/s, epoch=63/100, avg_epoch_loss=-.417]
# 100%|██████████| 50/50 [00:02<00:00, 18.16it/s, epoch=64/100, avg_epoch_loss=-.27]
# 100%|██████████| 50/50 [00:02<00:00, 18.28it/s, epoch=65/100, avg_epoch_loss=-.314]
# 100%|██████████| 50/50 [00:02<00:00, 18.13it/s, epoch=66/100, avg_epoch_loss=-.528]
# 100%|██████████| 50/50 [00:02<00:00, 18.25it/s, epoch=67/100, avg_epoch_loss=-.355]
# 100%|██████████| 50/50 [00:02<00:00, 18.43it/s, epoch=68/100, avg_epoch_loss=-.295]
# 100%|██████████| 50/50 [00:02<00:00, 18.10it/s, epoch=69/100, avg_epoch_loss=-.388]
# 100%|██████████| 50/50 [00:02<00:00, 18.38it/s, epoch=70/100, avg_epoch_loss=-.327]
# 100%|██████████| 50/50 [00:02<00:00, 18.14it/s, epoch=71/100, avg_epoch_loss=-.413]
# 100%|██████████| 50/50 [00:02<00:00, 18.09it/s, epoch=72/100, avg_epoch_loss=-.409]
# 100%|██████████| 50/50 [00:02<00:00, 18.31it/s, epoch=73/100, avg_epoch_loss=-.411]
# 100%|██████████| 50/50 [00:02<00:00, 18.45it/s, epoch=74/100, avg_epoch_loss=-.537]
# 100%|██████████| 50/50 [00:02<00:00, 18.44it/s, epoch=75/100, avg_epoch_loss=-.425]
# 100%|██████████| 50/50 [00:02<00:00, 18.45it/s, epoch=76/100, avg_epoch_loss=-.606]
# 100%|██████████| 50/50 [00:02<00:00, 18.28it/s, epoch=77/100, avg_epoch_loss=-.539]
# 100%|██████████| 50/50 [00:02<00:00, 18.45it/s, epoch=78/100, avg_epoch_loss=-.438]
# 100%|██████████| 50/50 [00:02<00:00, 18.32it/s, epoch=79/100, avg_epoch_loss=-.395]
# 100%|██████████| 50/50 [00:02<00:00, 17.88it/s, epoch=80/100, avg_epoch_loss=-.367]
# 100%|██████████| 50/50 [00:02<00:00, 17.72it/s, epoch=81/100, avg_epoch_loss=-.345]
# 100%|██████████| 50/50 [00:02<00:00, 18.53it/s, epoch=82/100, avg_epoch_loss=-.437]
# 100%|██████████| 50/50 [00:02<00:00, 18.36it/s, epoch=83/100, avg_epoch_loss=-.404]
# 100%|██████████| 50/50 [00:02<00:00, 18.04it/s, epoch=84/100, avg_epoch_loss=-.526]
# 100%|██████████| 50/50 [00:02<00:00, 17.68it/s, epoch=85/100, avg_epoch_loss=-.371]
# 100%|██████████| 50/50 [00:02<00:00, 17.94it/s, epoch=86/100, avg_epoch_loss=-.501]
# 100%|██████████| 50/50 [00:02<00:00, 17.75it/s, epoch=87/100, avg_epoch_loss=-.452]
# 100%|██████████| 50/50 [00:02<00:00, 17.96it/s, epoch=88/100, avg_epoch_loss=-.391]
# 100%|██████████| 50/50 [00:02<00:00, 17.42it/s, epoch=89/100, avg_epoch_loss=-.537]
# 100%|██████████| 50/50 [00:02<00:00, 17.94it/s, epoch=90/100, avg_epoch_loss=-.375]
# 100%|██████████| 50/50 [00:02<00:00, 17.87it/s, epoch=91/100, avg_epoch_loss=-.338]
# 100%|██████████| 50/50 [00:02<00:00, 17.83it/s, epoch=92/100, avg_epoch_loss=-.449]
# 100%|██████████| 50/50 [00:02<00:00, 18.24it/s, epoch=93/100, avg_epoch_loss=-.409]
# 100%|██████████| 50/50 [00:02<00:00, 18.22it/s, epoch=94/100, avg_epoch_loss=-.407]
# 100%|██████████| 50/50 [00:02<00:00, 18.24it/s, epoch=95/100, avg_epoch_loss=-.311]
# 100%|██████████| 50/50 [00:02<00:00, 18.28it/s, epoch=96/100, avg_epoch_loss=-.553]
# 100%|██████████| 50/50 [00:02<00:00, 18.60it/s, epoch=97/100, avg_epoch_loss=-.569]
# 100%|██████████| 50/50 [00:02<00:00, 18.54it/s, epoch=98/100, avg_epoch_loss=-.506]
# 100%|██████████| 50/50 [00:02<00:00, 18.43it/s, epoch=99/100, avg_epoch_loss=-.515]
# 100%|██████████| 50/50 [00:02<00:00, 18.50it/s, epoch=100/100, avg_epoch_loss=-.338]

# %%
valid = pd.read_csv('monthly_validate.csv')
valid.reset_index(inplace=True)

# %%
valid
# Out:
#    index  Unnamed: 0       datum  RemediMax  VitaFlux  SynaptraZol  \
# 0      0          60  2022-01-30     179.70   222.351        99.70
# 1      1          61  2022-02-27     133.73   142.155       110.20
# 2      2          62  2022-03-30     154.52   113.118        83.35
# 3      3          63  2022-04-29     161.39   100.165        88.10
# 4      4          64  2022-05-30     168.04    97.258       104.10
# 5      5          65  2022-06-29     151.54   101.627       103.20
# 6      6          66  2022-07-30     181.00   103.541        92.80
# 7      7          67  2022-08-30     181.91    88.269        84.20
# 8      8          68  2022-09-29     161.07   111.437        93.50
# 9      9          69  2022-10-30      44.37    37.300        20.65
#
#    NeuroRevive  Immunoxen  RemediSol  Vitalisol  RestoraZen
# 0     1660.612      295.2       23.0      386.0       41.30
# 1     1001.212      249.4       12.0      226.0       69.50
# 2      941.050      301.4       19.0      257.0      169.50
# 3      647.650      299.4       22.0      259.0      179.10
# 4      703.562      265.8       26.0      322.0      135.40
# 5      610.000      193.0       25.0      142.0      156.04
# 6      649.800      250.6       20.0      115.0      105.20
# 7      518.100      237.0       26.0      145.0       97.30
# 8      984.480      227.8       16.0      161.0      109.10
# 9      295.150       86.0        7.0       37.0       11.13

# %%
mx.random.seed(546781345)
np.random.seed(546781345)

forecast_it, ts_it = make_evaluation_predictions(
dataset=train_ds,  # test dataset
predictor=predictor,  # predictor
num_samples=100,  # number of sample paths we want for evaluation
)
forecasts = list(forecast_it)
tss = list(ts_it)

# %%
results_median = pd.DataFrame()
actual = pd.DataFrame()
results_mean = pd.DataFrame()

# %%
for i,id in zip(range(len(items)),items):
    results_median[id] = forecasts[i].median
    results_mean[id] = forecasts[i].mean

# %%
def smape(float(actual),float(forecast)):
    return np.mean(2*abs(actual-forecast)/(abs(actual)+abs(forecast)))
# Out:
#   File "<ipython-input-84-cbdb1550480a>", line 1
#     def smape(float(actual),float(forecast)):
#                    ^
# SyntaxError: invalid syntax

# %%
def mape(actual,forecast):
    return np.mean(abs(actual - forecast)/actual)

# %%
def mean_confidence_interval(data, confidence=0.95):
    a = 1.0*data
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return (m, m-h, m+h)

# %%
predictions = pd.DataFrame()
pred_temp=[]
time = []
ID = []
for i,id in zip(range(len(items)),items):
    results_mean[id] = forecasts[i].mean
    results_median[id] = forecasts[i].median
    actual[id] = tss[i].values.reshape(-1)[-12:]
    quantile_1[id] = forecasts[i].quantile(0.05)
    quantile_2[id] = forecasts[i].quantile(0.95)
for id,pred in zip(df_train['ID'].unique(),prediction):
#     predictions[id] = pred.mean
    dat = pd.DataFrame(data=pred.samples)
    date =datetime.datetime.strptime('2020-08-01', "%Y-%m-%d").date()
    for i in range(dat.shape[1]):
        conf = mean_confidence_interval(dat.loc[:,i].values.flatten(),confidence = 95/100)
        pred_temp.append(conf)
        if freq=='M':
            date += relativedelta(months=+1)
        time.append(date)
        ID.append(id)
predictions = pd.DataFrame(pred_temp,columns = ['Mean','Lower_Bound','Upper_bound'])
#         predictions[predictions<0]=0
predictions = predictions.round(0)
predictions.insert(0,'ID',ID)
predictions.insert(1,'time',time)

# %%
results_mean = pd.DataFrame()
results_median = pd.DataFrame()
actual = pd.DataFrame()
quantile_1 = pd.DataFrame()
quantile_2 = pd.DataFrame()
results_mean['date'] = tss[0].index[-12:]
results_median['date'] = tss[0].index[-12:]
actual['date'] = tss[0].index[-12:]
quantile_1['date'] = tss[0].index[-12:]
quantile_2['date'] = tss[0].index[-12:]
for i,id in zip(range(len(items)),items):
    results_mean[id] = forecasts[i].mean
    results_median[id] = forecasts[i].median
    actual[id] = tss[i].values.reshape(-1)[-12:]
    quantile_1[id] = forecasts[i].quantile(0.05)
    quantile_2[id] = forecasts[i].quantile(0.95)

# %%
actual= pd.melt(actual,id_vars='date',value_vars=['RemediMax','VitaFlux','SynaptraZol','NeuroRevive','Immunoxen','RemediSol','Vitalisol','RestoraZen'],
               value_name='actual')

# %%
results_mean= pd.melt(results_mean,id_vars='date',value_vars=['RemediMax','VitaFlux','SynaptraZol','NeuroRevive','Immunoxen','RemediSol','Vitalisol','RestoraZen'],
               value_name='forecast_mean')

# %%
results_median= pd.melt(results_median,id_vars='date',value_vars=['RemediMax','VitaFlux','SynaptraZol','NeuroRevive','Immunoxen','RemediSol','Vitalisol','RestoraZen'],
               value_name='forecast_median')

# %%
quantile_1= pd.melt(quantile_1,id_vars='date',value_vars=['RemediMax','VitaFlux','SynaptraZol','NeuroRevive','Immunoxen','RemediSol','Vitalisol','RestoraZen'],
               value_name='quantile_0.05')

# %%
quantile_2= pd.melt(quantile_2,id_vars='date',value_vars=['RemediMax','VitaFlux','SynaptraZol','NeuroRevive','Immunoxen','RemediSol','Vitalisol','RestoraZen'],
               value_name='quantile_0.95')

# %%
final_results = pd.merge(actual,results_mean,on=['date','variable'],how='left')

# %%
final_results = pd.merge(final_results,quantile_1,on=['date','variable'],how='left')

# %%
final_results = pd.merge(final_results,quantile_2,on=['date','variable'],how='left')

# %%
final_results['date'] = final_results['date'].dt.date

# %%
final_results['model'] = 'deepar'
final_results['granularity'] = 'M'
